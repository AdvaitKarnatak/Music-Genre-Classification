# %%
import numpy as np
import pandas as pd
import os

# %%
import IPython.display as ipd
import matplotlib.pyplot as plt

# %%
file1 = "Data/genres_original/pop/pop.00003.wav"

# %%
import librosa
import librosa.display

# %%
plt.figure(figsize=(16,9))
data1, sr1=librosa.load(file1)
librosa.display.waveshow(data1,sr=sr1)
ipd.Audio(file1)
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/x-wav;base64,..." type="audio/x-wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
import numpy as np

# %%
data1
# Out:
# array([-0.0249939 , -0.01815796, -0.02023315, ..., -0.36505127,
#        -0.4237976 , -0.42385864], dtype=float32)

# %%
sr1
# Out:
# 22050

# %%
import pandas as pd

data=pd.read_csv('Data/features_3_sec.csv')
data.head(10)
#data.shape
# Out:
#             filename  length  chroma_stft_mean  chroma_stft_var  rms_mean  \
# 0  blues.00000.0.wav   66149          0.335406         0.091048  0.130405
# 1  blues.00000.1.wav   66149          0.343065         0.086147  0.112699
# 2  blues.00000.2.wav   66149          0.346815         0.092243  0.132003
# 3  blues.00000.3.wav   66149          0.363639         0.086856  0.132565
# 4  blues.00000.4.wav   66149          0.335579         0.088129  0.143289
# 5  blues.00000.5.wav   66149          0.376670         0.089702  0.132618
# 6  blues.00000.6.wav   66149          0.379909         0.088827  0.130335
# 7  blues.00000.7.wav   66149          0.331880         0.092119  0.140600
# 8  blues.00000.8.wav   66149          0.347877         0.094209  0.133130
# 9  blues.00000.9.wav   66149          0.358061         0.082957  0.115312
#
#     rms_var  spectral_centroid_mean  spectral_centroid_var  \
# 0  0.003521             1773.065032          167541.630869
# ...

# %%
import pandas as pd

data=pd.read_csv('Data/features_30_sec.csv')
data.head(10)
#data.shape
# Out:
#           filename  length  chroma_stft_mean  chroma_stft_var  rms_mean  \
# 0  blues.00000.wav  661794          0.350088         0.088757  0.130228
# 1  blues.00001.wav  661794          0.340914         0.094980  0.095948
# 2  blues.00002.wav  661794          0.363637         0.085275  0.175570
# 3  blues.00003.wav  661794          0.404785         0.093999  0.141093
# 4  blues.00004.wav  661794          0.308526         0.087841  0.091529
# 5  blues.00005.wav  661794          0.302456         0.087532  0.103494
# 6  blues.00006.wav  661794          0.291328         0.093981  0.141874
# 7  blues.00007.wav  661794          0.307955         0.092903  0.131822
# 8  blues.00008.wav  661794          0.408879         0.086512  0.142416
# 9  blues.00009.wav  661794          0.273950         0.092316  0.081314
#
#     rms_var  spectral_centroid_mean  spectral_centroid_var  \
# 0  0.002827             1784.165850           1.297741e+05
# ...

# %%
def features_extractor(file):
    try:
        audio, sample_rate = librosa.load(file, res_type='kaiser_fast')
        mfccs_features = librosa.feature.mfcc(y=audio, sr=sample_rate, n_mfcc=40)
        mfccs_scaled_features = np.mean(mfccs_features.T, axis=0)
        return mfccs_scaled_features
    except Exception as e:
        print(f"Error loading {file}: {e}")
        return None

# %%
extracted_features = []
corrupt_files = []

# %%
from tqdm import tqdm

for index_num, row in tqdm(data.iterrows(), total=data.shape[0]):
    file_name = os.path.join(os.path.abspath("Data/genres_original"), row['label'], str(row['filename']))
    features = features_extractor(file_name)
    if features is not None:
        extracted_features.append([features, row['label']])
    else:
        corrupt_files.append(index_num)
# Out:
#  55%|██████████████████████                  | 553/1000 [00:39<00:35, 12.44it/s]/var/folders/l0/1187xf1x5bz0ltr7dq12m2f40000gn/T/ipykernel_107/1263226154.py:3: UserWarning: PySoundFile failed. Trying audioread instead.
#   audio, sample_rate = librosa.load(file, res_type='kaiser_fast')
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/librosa/core/audio.py:184: FutureWarning: librosa.core.audio.__audioread_load
# 	Deprecated as of librosa version 0.10.0.
# 	It will be removed in librosa version 1.0.
#   y, sr_native = __audioread_load(path, offset, duration, dtype)
#  56%|██████████████████████▎                 | 557/1000 [00:39<00:34, 12.66it/s]
# Error loading /Users/advaitk/Desktop/Music Genre Classification/Data/genres_original/jazz/jazz.00054.wav:
# 100%|███████████████████████████████████████| 1000/1000 [01:09<00:00, 14.43it/s]

# %%
data.shape
# Out:
# (1000, 60)

# %%
data.drop(labels=corrupt_files, axis=0, inplace=True)

# %%
data.shape
# Out:
# (999, 60)

# %%
finaldata = pd.DataFrame(extracted_features, columns=['feature', 'label'])

# %%
finaldata
# Out:
#                                                feature  label
# 0    [-113.59882, 121.57067, -19.162262, 42.36394, ...  blues
# 1    [-207.52383, 123.98514, 8.947019, 35.86715, 2....  blues
# 2    [-90.757164, 140.44087, -29.084547, 31.686693,...  blues
# 3    [-199.57513, 150.0861, 5.663404, 26.855282, 1....  blues
# 4    [-160.35417, 126.209496, -35.581394, 22.139256...  blues
# ..                                                 ...    ...
# 994  [-153.63004, 109.90478, -23.091644, 59.014496,...   rock
# 995  [-142.41621, 116.20546, -32.160263, 49.11151, ...   rock
# 996  [-124.989655, 115.18234, -47.985886, 52.820343...   rock
# 997  [-225.03336, 123.657265, -9.745124, 56.613846,...   rock
# 998  [-235.20059, 123.87175, -22.546131, 52.951675,...   rock
#
# [999 rows x 2 columns]

# %%
finaldata['label'].value_counts()
# Out:
# label
# blues        100
# classical    100
# country      100
# disco        100
# hiphop       100
# metal        100
# pop          100
# reggae       100
# rock         100
# jazz          99
# Name: count, dtype: int64

# %%
features = np.array(finaldata['feature'].tolist())
label = np.array(finaldata['label'].tolist())

# %%
# !pip install "tensorflow"

# %%
import tensorflow as tf

from tensorflow.keras.utils import to_categorical
from sklearn.preprocessing import LabelEncoder

label = to_categorical(LabelEncoder().fit_transform(label))

# %%
label.shape
# Out:
# (999, 10)

# %%
from sklearn.model_selection import train_test_split

features_train, features_test, label_train, label_test = train_test_split(features, label, test_size=0.2, random_state=0)

# %%
features_train.shape
# Out:
# (799, 40)

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout, Activation, Flatten
from tensorflow.keras.optimizers import Adam

model = Sequential([
    Dense(1024, activation='relu', input_shape=(40,)),
    Dropout(0.3),
    Dense(512, activation='relu'),
    Dropout(0.3),
    Dense(256, activation='relu'),
    Dropout(0.3),
    Dense(256, activation='relu'),
    Dropout(0.3),
    Dense(128, activation='relu'),
    Dropout(0.3),
    Dense(64, activation='relu'),
    Dropout(0.3),
    Dense(32, activation='relu'),
    Dropout(0.3),
    Dense(10, activation='softmax') 
])
# Out:
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/keras/src/layers/core/dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)

# %%
model.summary()
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ dense (Dense)                   │ (None, 1024)           │        41,984 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout (Dropout)               │ (None, 1024)           │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 512)            │       524,800 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_1 (Dropout)             │ (None, 512)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_2 (Dense)                 │ (None, 256)            │       131,328 │
# ...

# %%
model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])

# %%
from tensorflow.keras.callbacks import EarlyStopping

early_stopping = EarlyStopping(monitor='val_accuracy', patience=20, restore_best_weights=True)

history = model.fit(features_train, label_train, epochs=5000, batch_size=32, validation_data=(features_test, label_test), callbacks=[early_stopping])
# Out:
# Epoch 1/5000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 5s 53ms/step - accuracy: 0.1178 - loss: 5.6198 - val_accuracy: 0.0900 - val_loss: 2.2849
# Epoch 2/5000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 46ms/step - accuracy: 0.1173 - loss: 2.5413 - val_accuracy: 0.0850 - val_loss: 2.2946
# Epoch 3/5000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 34ms/step - accuracy: 0.1218 - loss: 2.3686 - val_accuracy: 0.1400 - val_loss: 2.2811
# Epoch 4/5000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.1002 - loss: 2.3447 - val_accuracy: 0.1300 - val_loss: 2.2618
# Epoch 5/5000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - accuracy: 0.1148 - loss: 2.3378 - val_accuracy: 0.1400 - val_loss: 2.2423
# Epoch 6/5000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 24ms/step - accuracy: 0.1310 - loss: 2.2992 - val_accuracy: 0.1750 - val_loss: 2.1771
# Epoch 7/5000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 24ms/step - accuracy: 0.1546 - loss: 2.2129 - val_accuracy: 0.1700 - val_loss: 2.1182
# Epoch 8/5000
# ...

# %%
test_loss, test_acc = model.evaluate(features_test, label_test, verbose=2)
print(f'\nTest accuracy: {test_acc}')
# Out:
# 7/7 - 0s - 5ms/step - accuracy: 0.6700 - loss: 2.6494
#
# Test accuracy: 0.6700000166893005

# %%
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('Model accuracy')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.legend(['Train', 'Test'], loc='upper left')
plt.show()

# %%
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('Model loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['Train', 'Test'], loc='upper left')
plt.show()

# %%
test1 = "awagaman reel.wav"
audio1, sr1 = librosa.load(test1)
mfccs_features = librosa.feature.mfcc(y=audio1, sr = sr1, n_mfcc=40)
mfccs_features_scaled = np.mean(mfccs_features.T, axis=0)

# %%
mfccs_features_scaled
# Out:
# array([-68.31906   ,  99.02438   ,  32.366184  ,  28.282778  ,
#         13.465893  ,  -7.439409  ,  -2.5705166 ,  -2.3421419 ,
#         -4.1858006 ,   7.1573544 ,  -7.4931016 ,  -2.998165  ,
#          4.427644  ,  -3.524327  ,  -0.5847135 ,   7.529974  ,
#         -5.9264107 ,   9.592964  ,  -3.6395733 ,  -0.18004602,
#         -0.20221981,   5.0286646 ,  -7.8511443 ,   2.0598416 ,
#         -3.2015173 ,  -1.8876318 ,  -2.4833286 ,   1.8775048 ,
#          2.3297787 ,   3.5328493 ,   1.4136719 ,   1.3437364 ,
#         -1.4124702 ,   1.5395421 ,  -0.77708405,  -1.4127406 ,
#         -2.5045853 ,  -1.9746406 ,  -3.4659007 ,  -1.7358135 ],
#       dtype=float32)

# %%
mfccs_features_scaled = mfccs_features_scaled.reshape(1,-1)

# %%
predicted_label = model.predict(mfccs_features_scaled)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step

# %%
predicted_class = np.argmax(predicted_label, axis=1)
print(f'Predicted class: {predicted_class}')
# Out:
# Predicted class: [4]

# %%
test1 = "becon.wav"
audio1, sr1 = librosa.load(test1)
mfccs_features = librosa.feature.mfcc(y=audio1, sr = sr1, n_mfcc=40)
mfccs_features_scaled = np.mean(mfccs_features.T, axis=0)

# %%
mfccs_features_scaled
# Out:
# array([-1.1405377e+02,  9.9582047e+01,  3.1847519e+01,  3.3095650e+01,
#         1.2622780e+01,  7.4992189e+00,  1.7848401e-01,  1.2537281e+01,
#         4.2712302e+00,  9.1395006e+00,  1.6152501e+00,  7.8136353e+00,
#         6.4918540e-02,  2.9699414e+00,  2.8176662e-01,  3.9608119e+00,
#         4.6285927e-01,  2.1829207e+00,  2.1248646e+00,  5.1876507e+00,
#         2.3588696e+00,  4.3136249e+00,  1.4904736e-01,  2.4657693e+00,
#        -4.4226938e-01,  2.6584141e+00, -3.8562322e-01, -4.2418420e-02,
#        -4.5492659e+00,  4.5689800e-01,  2.7508965e+00,  6.1812057e+00,
#        -1.2919617e+00, -6.7368064e+00, -7.0137324e+00, -3.2307506e+00,
#        -3.0529597e+00,  9.8583740e-01,  9.4065398e-02,  2.1749029e+00],
#       dtype=float32)

# %%
mfccs_features_scaled = mfccs_features_scaled.reshape(1,-1)

# %%
predicted_label = model.predict(mfccs_features_scaled)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step

# %%
predicted_class = np.argmax(predicted_label, axis=1)
print(f'Predicted class: {predicted_class}')
# Out:
# Predicted class: [2]

# %%
test1 = "dard verse.wav"
audio1, sr1 = librosa.load(test1)
mfccs_features = librosa.feature.mfcc(y=audio1, sr = sr1, n_mfcc=40)
mfccs_features_scaled = np.mean(mfccs_features.T, axis=0)

mfccs_features_scaled

mfccs_features_scaled = mfccs_features_scaled.reshape(1,-1)

predicted_label = model.predict(mfccs_features_scaled)

predicted_class = np.argmax(predicted_label, axis=1)
print(f'Predicted class: {predicted_class}')
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# Predicted class: [5]
